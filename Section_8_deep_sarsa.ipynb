# %% [markdown]
# <div style="text-align:center">
#     <h1>
#         Deep SARSA
#     </h1>
# </div>
#
# <br><br>
#
# <div style="text-align:center">
#
# In this notebook, we extend the SARSA algorithm to use function approximators (Neural Networks). The resulting algorithm is known as Deep SARSA.
# </div>
#
# <br><br>
# <div style="text-align:center">
#     <b>This notebook belongs to section 8 of the course "Reinforcement Learning: beginner to master".</b>
#     <br><br>
#     <a href="https://www.udemy.com">Reinforcement Learning: beginner to master</a> (English)
#     <br>
#     <a href="https://www.udemy.com">Reinforcement Learning: de principiante a maestro</a> (Spanish)
# </div>
#
# <br>
#
# <table style="width:35%">
#   <tr style="background-color: transparent">
#     <td style="width: 45%">
#         <a target="_parent" href="https://www.evlabs.io" style="float: center">
#             <img src="img/evlabs-square.png" width="75"/>
#         </a>
#     </td>
#     <td valign="bottom">
#         <a target="_parent" href="https://www.youtube.com/channel/UCksRNSzWuMV5IfdrPlglqqw">
#             <img src="img/YouTube.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://www.linkedin.com/company/evlabs">
#             <img src="img/LinkedIn.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://twitter.com/evelabs">
#             <img src="img/Twitter.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://github.com/escape-velocity-labs/">
#             <img src="img/GitHub.png" width="35"/>
#         </a>
#     </td>
#
#   </tr>
#   <tr style="background-color: transparent">
#     <th style="text-align: center; width: 70%">Escape Velocity Labs</th>
#   </tr>
#
# </table>
#
# <br>

# %% [markdown]
# ## Import the necessary software libraries:

# %%
import matplotlib.pyplot as plt

import random
import copy
import tqdm

from utils import plot_cost_to_go, plot_max_q, plot_stats, seed_everything, test_agent

import gym

import torch
import torch.nn.functional as F
from torch import nn
from torch.optim import AdamW

# %matplotlib notebook

# %% [markdown]
# ## Create and prepare the environment

# %% [markdown]
# ### Create the environment

# %%
env = gym.make('MountainCar-v0')
seed_everything(env)
# Out:
# /Users/bourhandernayka/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/gym/core.py:172: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed) instead.
#   deprecation(

# %%
state_dims = env.observation_space.shape[0]
num_actions = env.action_space.n
print(f'MountainCar env: State Dimensions: {state_dims}, Number of Actions: {num_actions}')
# Out:
# MountainCar env: State Dimensions: 2, Number of Actions: 3

# %% [markdown]
# ### Prepare the environment to work with PyTorch

# %%
class PreprocessEnv(gym.Wrapper):

    def __init__(self, env):
        gym.Wrapper.__init__(self, env)

    def reset(self):
        state = self.env.reset()

        return torch.from_numpy(state).unsqueeze(dim=0).float()

    def step(self, action):
        action = action.item()
        next_state, reward, done, info = self.env.step(action)
        
        next_state = torch.from_numpy(next_state).unsqueeze(dim=0).float()
        reward = torch.tensor(reward).view([1, -1]).float()
        done = torch.tensor(done).view([1, -1])

        return next_state, reward, done, info

# %%
env = PreprocessEnv(env)

# %%
state = env.reset()
action = torch.tensor(0)
next_state, reward, done, _ = env.step(action)

print(f'Sample State: {state}')
print(f'Next State: {next_state}, Reward: {reward}, Done: {done}')
# Out:
# Sample State: tensor([[-0.4452,  0.0000]])
# Next State: tensor([[-0.4468, -0.0016]]), Reward: tensor([[-1.]]), Done: tensor([[False]])

# %% [markdown]
# ## Create the Q-Network and policy
#
# <br><br>

# %% [markdown]
# ![Screenshot%202021-03-11%20at%2020.23.56.png](attachment:Screenshot%202021-03-11%20at%2020.23.56.png)

# %% [markdown]
# ### Create the Q-Network: $\hat q(s,a| \theta)$

# %%
h1, h2 = 128, 64

q_network = nn.Sequential(
    nn.Linear(state_dims, h1),  # nn.Linear state * W + b
    nn.ReLU(),                  # nn.ReLU 
    nn.Linear(h1, h2),
    nn.ReLU(),
    nn.Linear(h2, num_actions),
    # nn.ReLU(), 
)

# %% [markdown]
# ### Create the target Q-Network: $\hat q(s, a|\theta_{targ})$

# %%
target_q_network = copy.deepcopy(q_network)
target_q_network = target_q_network.eval()

# %% [markdown]
# ### Create the $\epsilon$-greedy policy: $\pi(s)$

# %%
def policy(state, epsilon=0.):    
    if torch.rand(1) < epsilon:
        return torch.randint(num_actions, (1, 1))
    else:
        av = q_network(state).detach()
        return torch.argmax(av, dim=-1, keepdim=True)

# %% [markdown]
# ### Plot the cost to go: $ - \max_a \hat q(s,a|\theta)$

# %%
# %matplotlib inline
plot_cost_to_go(env, q_network, xlabel='Car Position', ylabel='Car Velocity')

# %% [markdown]
# ## Create the Experience Replay buffer
#
# <br>
# <div style="text-align:center">
#     <p>A simple buffer that stores transitions of arbitrary values, adapted from
#     <a href="https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html#training">this source.</a></p>
# </div>
#
# ![Screenshot%202021-03-11%20at%2020.38.28.png](attachment:Screenshot%202021-03-11%20at%2020.38.28.png)

# %%
class ReplayMemory:

    def __init__(self, capacity=10_000_000) -> None:
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def insert(self, transition):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = transition
        self.position = (self.position+1) % self.capacity
    
    def sample(self, batch_size):
        assert self.can_sample(batch_size)

        batch = random.sample(self.memory, batch_size)

        batch = zip(*batch)

        return [torch.cat(items) for items in batch]  # N x D

    def can_sample(self, batch_size):
        return len(self) >= batch_size * 10

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ## Implement the algorithm
#
# </br></br>

# %% [markdown]
# ![Screenshot%202021-03-11%20at%2019.03.36.png](attachment:Screenshot%202021-03-11%20at%2019.03.36.png)

# %%
def deep_sarsa(q_network, policy, episodes, 
               alpha=0.001, batch_size=32, 
               gamma=0.99, epsilon=0.05):
    optim = AdamW(q_network.parameters(), lr=alpha)
    memory = ReplayMemory(capacity=1_000_000)
    stats = {'MSE LOSS': [], 'Returns': []}

    for episode in tqdm.tqdm(range(1, episodes+1)):
        state = env.reset()
        done = False
        ep_return = 0.
        
        while not done:
            action = policy(state, epsilon)
            next_state, reward, done, _ = env.step(action)
            memory.insert([state, action, reward, done, next_state])

            if memory.can_sample(batch_size):
                state_b, action_b, reward_b, done_b, next_state_b = \
                    memory.sample(batch_size)

                qsa_b = q_network(state_b).gather(1, action_b)
                
                next_action_b = policy(next_state_b, epsilon)
                next_qsa_b = target_q_network(next_state_b).gather(1, next_action_b)
                target_b = reward_b + ~done_b * gamma * next_qsa_b

                loss = F.mse_loss(qsa_b, target_b)
                q_network.zero_grad()
                loss.backward()

                optim.step()

                stats['MSE LOSS'].append(loss.item())

            state = next_state
            ep_return += reward.item()

        stats['Returns'].append(ep_return)

        if episode % 10 == 0:
            target_q_network.load_state_dict(q_network.state_dict())

    return stats

# %%
stats = deep_sarsa(q_network, policy, episodes=1_500, epsilon=0.01)
# Out:
# 100%|██████████| 1500/1500 [07:47<00:00,  3.21it/s]

# %% [markdown]
# ## Show results

# %% [markdown]
# ### Plot execution stats

# %%
plot_stats(stats)

# %% [markdown]
# ### Plot the cost to go: $ - \max_a \hat q(s,a|\theta)$

# %%
# %matplotlib inline
plot_cost_to_go(env, q_network, xlabel='Car Position', ylabel='Car Velocity')

# %% [markdown]
# ### Show resulting policy: $\pi(s)$

# %%
plot_max_q(env, q_network, xlabel='Car Position', ylabel='Car Velocity', action_labels=['Backward', 'Do Nothing', 'Forward'])

# %% [markdown]
# ### Test the resulting agent

# %%
# %matplotlib inline
test_agent(env, policy, episodes=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/PIL/ImageFile.py:503, in _save(im, fp, tile, bufsize)
#     502 try:
# --> 503     fh = fp.fileno()
#     504     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 test_agent(env, policy, episodes=2)
#
# File ~/Desktop/myfiles_local/beginner_master_rl/utils.py:121, in test_agent(env, policy, episodes)
#     119 img.set_data(env.render(mode='rgb_array'))
#     120 plt.axis('off')
# --> 121 display.display(plt.gcf())
#     122 display.clear_output(wait=True)
#     123 state = next_state
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/IPython/core/formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/IPython/core/formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/matplotlib/backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
#    2336     # force the figure dpi to 72), so we need to set it again here.
#    2337     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338         result = print_method(
#    2339             filename,
#    2340             facecolor=facecolor,
#    2341             edgecolor=edgecolor,
#    2342             orientation=orientation,
#    2343             bbox_inches_restore=_bbox_inches_restore,
#    2344             **kwargs)
#    2345 finally:
#    2346     if bbox_inches and restore_bbox:
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2200     optional_kws = {  # Passed by print_figure for other renderers.
#    2201         "dpi", "facecolor", "edgecolor", "orientation",
#    2202         "bbox_inches_restore"}
#    2203     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206 else:  # Let third-parties do as they see fit.
#    2207     print_method = meth
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:410, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     400     deprecation_addendum = (
#     401         f"If any parameter follows {name!r}, they should be passed as "
#     402         f"keyword, not positionally.")
#     403     warn_deprecated(
#     404         since,
#     405         name=repr(name),
#    (...)
#     408                  else deprecation_addendum,
#     409         **kwargs)
# --> 410 return func(*inner_args, **inner_kwargs)
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:517, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     468 @_api.delete_parameter("3.5", "args")
#     469 def print_png(self, filename_or_obj, *args,
#     470               metadata=None, pil_kwargs=None):
#     471     """
#     472     Write the figure to a PNG file.
#     473
#    (...)
#     515         *metadata*, including the default 'Software' key.
#     516     """
# --> 517     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:464, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     459 """
#     460 Draw the canvas, then save it using `.image.imsave` (to which
#     461 *pil_kwargs* and *metadata* are forwarded).
#     462 """
#     463 FigureCanvasAgg.draw(self)
# --> 464 mpl.image.imsave(
#     465     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     466     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/matplotlib/image.py:1664, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1662 pil_kwargs.setdefault("format", format)
#    1663 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1664 image.save(fname, **pil_kwargs)
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/PIL/Image.py:2353, in Image.save(self, fp, format, **params)
#    2350         fp = builtins.open(filename, "w+b")
#    2352 try:
# -> 2353     save_handler(self, fp, filename)
#    2354 except Exception:
#    2355     if open_fp:
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/PIL/PngImagePlugin.py:1397, in _save(im, fp, filename, chunk, save_all)
#    1395     _write_multiple_frames(im, fp, chunk, rawmode, default_image, append_images)
#    1396 else:
# -> 1397     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1399 if info:
#    1400     for info_chunk in info.chunks:
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/PIL/ImageFile.py:507, in _save(im, fp, tile, bufsize)
#     505     _encode_tile(im, fp, tile, bufsize, fh)
#     506 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 507     _encode_tile(im, fp, tile, bufsize, None, exc)
#     508 if hasattr(fp, "flush"):
#     509     fp.flush()
#
# File ~/Desktop/myfiles_local/beginner_master_rl/.venv/lib/python3.10/site-packages/PIL/ImageFile.py:526, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     523 if exc:
#     524     # compress to Python file-compatible object
#     525     while True:
# --> 526         l, s, d = encoder.encode(bufsize)
#     527         fp.write(d)
#     528         if s:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Resources

# %% [markdown]
# [[1] Deep Reinforcement Learning with Experience Replay Based on SARSA](https://www.researchgate.net/publication/313803199_Deep_reinforcement_learning_with_experience_replay_based_on_SARSA)
